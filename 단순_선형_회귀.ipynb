# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Importing the libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Salary_Data.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = regression.predict(x_test)

# %% [markdown]
# ## Visualising the Training set results

# %%
plt.scatter(x_train, y_train, color='red') # 빨간색 점은 실제 연봉을 의미
plt.plot(x_train, regression.predict(x_train), color = 'blue') # 파란색 선은 예측 연봉을 의미
# x_train이 x축(경력), regression.predict(x_train)이 y축(연봉 예측값)이다. 즉 경력에 따른 연봉 예측값이 선형으로 그려진다.
plt.title('rudfurdp Ekfms dusqhd qusghk')
plt.xlabel('rudfur')
plt.ylabel('dusqhd')
plt.show()

# %% [markdown]
# ## Visualising the Test set results

# %%
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_train, regression.predict(x_train))
plt.title('rudfurdp Ekfms')
plt.xlabel('rudqhd')
plt.ylabel('qusghk')
plt.show()

# %% [markdown]
# 두번 째 줄에 최종적으로 구할 회귀선은 고유한 방정식으로부터 도출되는 결과이므로 테스트 세트의 예측 임금은 훈련 세트의 예측 임금과 똑같은 회귀 선상에 놓이게 되므로 x_train을 x_test로 바꿀 필요가 없다.그러므로 첫번 째 줄에 x_train, y_train만 x_test, y_test로 바꾸어준다.
#
# 즉 훈련 세트의 예측 임금인 x_train의 좌표를 이용하든 테스트 세트의 예측 임금인 x_test를 이용하든 동일한 회귀선을 그린다.
